# %%
import pandas as pd
import numpy as np

# %%
df_ger = pd.read_csv('df_geracao_pb_75_ufv_eol.csv')
df_ger
# Out:
#                  Empreendimento Tipo de Geração  Potência Outorgada (kW)  \
# 0                    Millennium             EOL                  10200.0
# 1                       Vitória             EOL                   4500.0
# 2                    Presidente             EOL                   4800.0
# 3                       Camurim             EOL                   4800.0
# 4                      Albatroz             EOL                   4800.0
# ..                          ...             ...                      ...
# 68          Supermercado Guedes             UFV                    300.0
# 69                  LAMINOR_UFV             UFV                    140.0
# 70                       ITATEX             UFV                    108.0
# 71                    HUMAITA I             UFV                    200.0
# 72  LAMINOR MATRIZ AUTOPRODUTOR             UFV                    200.0
#
#                Latitude            Longitude        DscMuninicpios
# ...

# %%
df_eolica = pd.read_excel('perdas_restricao_estado_eolica_PB.xlsx')

# %%
df_eolica = df_eolica.drop(columns=['id_estado'])
df_eolica
# Out:
#                nom_usina   val_geracao  energia_gerada_possivel  \
# 0   CONJ. CHAFARIZ NORTE  1.852486e+06             1.865523e+06
# 1   CONJ. CHAFARIZ SUL I  1.785853e+06             1.796233e+06
# 2  CONJ. CHAFARIZ SUL II  2.188965e+06             2.198010e+06
# 3  CONJ. SERRA DO SERIDÓ  2.588225e+06             2.619163e+06
# 4                    NaN           NaN                      NaN
#
#    Perdas_Geração_Restrição_Sistema
# 0                        13036.8035
# 1                        10379.8415
# 2                         9044.6015
# 3                        30937.0285
# 4                        63398.2750

# %%
df_solar = pd.read_excel('perdas_restricao_estado_fotovoltaica_PB.xlsx')
df_solar = df_solar.drop(columns=['id_estado'])
df_solar
# Out:
#                                     nom_usina  val_geracao  \
# 0                                 CONJ. LUZIA  200102.5195
# 1                              CONJ. RIO ALTO  385759.2610
# 2  CONJUNTO FOTOVOLTAICO SANTA LUZIA II 500KV  383279.4755
# 3                                         NaN          NaN
#
#    energia_gerada_possivel  Perdas_Geração_Restrição_Sistema
# 0              205129.9115                         5027.3920
# 1              394020.7970                         8261.5360
# 2              392863.0490                         9583.5735
# 3                      NaN                        22872.5015

# %%
# Dicionário mapeando os empreendimentos às suas coordenadas
coordenadas = {
    "LAMINOR_UFV": (-6.3265408967843975, -37.70878547301616),
    "ITATEX": (-7.3283816143434874, -38.141135299999995),
    "HUMAITA I": (-7.212568818951673, -34.85277052883603),
    "LAMINOR MATRIZ AUTOPRODUTOR": (-6.3265408967843975, -37.70874255767205)
}
